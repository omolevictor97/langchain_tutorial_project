# %%
import os
from dotenv import load_dotenv
load_dotenv("../../.env")
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
text = "This is used to test OpenAI embedding technique"

vectors_result = embeddings.embed_query(text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 text = "This is used to test OpenAI embedding technique"
# ----> 3 vectors_result = embeddings.embed_query(text)
#
# File c:\Users\omole\anaconda3\envs\langchain_env\lib\site-packages\langchain_openai\embeddings\base.py:807, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     797 """Call out to OpenAI's embedding endpoint for embedding query text.
#     798
#     799 Args:
#    (...)
#     804     Embedding for the text.
#     805 """
#     806 self._ensure_sync_client_available()
# --> 807 return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\omole\anaconda3\envs\langchain_env\lib\site-packages\langchain_openai\embeddings\base.py:757, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
# ...

# %% [markdown]
# #### I need to buy some credit on OPENAI

# %% [markdown]
# Ordinarily, one can set the value of dimensions in OpenAI models

# %%
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large", dimensions=1024)
embeddings_1024
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x0000024A35B77DC0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x0000024A304221A0>, model='text-embedding-3-large', dimensions=1024, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %% [markdown]
# Data Ingestion
#    <>
# Data Splitting

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_loader = TextLoader(file_path="speech.txt")
docs = text_loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
final_docs = text_splitter.split_documents(docs)

# %% [markdown]
# Embedding and storage

# %%
from langchain_community.vectorstores import Chroma

# %%
db = Chroma().from_documents(final_docs, embeddings_1024)
db
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 db = Chroma().from_documents(final_docs, embeddings_1024)
#       2 db
#
# File c:\Users\omole\anaconda3\envs\langchain_env\lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
#     895     client=client,
# ...
