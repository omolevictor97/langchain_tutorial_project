# %% [markdown]
# ### Getting Started with Langchain and OpenAI
#
# - Get Setup with Langchain, LangSmith and LangServe
# - Use the most basic and most common components of Langchain: prompt templates, models and output parsers.
# - Build a simple application with LangChain
# - Trace the application with LangSmith
# - Serve the application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv('../../.env')
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
## LangSmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "None"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}} profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000002283C1B8E20> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002283C1BBE80> root_client=<openai.OpenAI object at 0x000002283C1B8DC0> root_async_client
# ...

# %%
llm.invoke("What is Generative AI")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File c:\Users\omole\anaconda3\envs\langchain_env\lib\site-packages\langchain_openai\chat_models\base.py:1904, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1903 else:
# -> 1904     raw_response = self.client.with_raw_response.create(**payload)
#    1905     response = raw_response.parse()
#
# File c:\Users\omole\anaconda3\envs\langchain_env\lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\omole\anaconda3\envs\langchain_env\lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# ...
